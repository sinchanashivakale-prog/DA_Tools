# %% [markdown]
# ### Pandas
#
# * Pandas is a powerful python library for manipulation and analysis of data.
#
# * It is a open source library.
#
# * fast(buit in top of  numpy), flexibal(different resource), productive library.

# %% [markdown]
# ### Install

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 2.2.3

# %% [markdown]
# #### Series - One dimensional array (data structure) with label

# %%
l1 = [1,2,3,4,5]
type(l1)
# Out:
# list

# %%
pd.Series(l1)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
s=pd.Series(l1,index = ['a','b','c','d','e'] ,name="myseries")

# %%
s
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# Name: myseries, dtype: int64

# %%
s['a']
# Out:
# np.int64(1)

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e'], dtype='object')

# %%
s.values
# Out:
# array([1, 2, 3, 4, 5])

# %%
s.index[0]
# Out:
# 'a'

# %% [markdown]
# ## Note : Index in series are imuutabale(can't change)

# %%
s.index[0] = '2'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 s.index[0] = '2'
#
# File c:\Users\klemp\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5371, in Index.__setitem__(self, key, value)
#    5369 @final
#    5370 def __setitem__(self, key, value) -> None:
# -> 5371     raise TypeError("Index does not support mutable operations")
#
# TypeError: Index does not support mutable operations

# %%
# Changing the index of a pandas series

s.rename(index={'b':'y'},inplace=True)

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: myseries, dtype: int64

# %% [markdown]
# ###  OR

# %%
s=s.rename(index={'b':'y'})

# %%
s
# Out:
# a    1
# y    2
# c    3
# d    4
# e    5
# Name: myseries, dtype: int64

# %% [markdown]
# #### DataFrame - Its a 2-D Arrar (Just like a Tables)

# %%
dict1 = {'Name': ['Virat','Rohit','Dhoni','Jadeja','Bumrah','Virat'],
         'Age': [34,33,40,32,30,35],
         'Marks' : [85,90,75,80,70,88],
         'Role': ['Batsman','Batsman','wicket keeper','All rounder','Bowler','Bowler']
         }

df = pd.DataFrame(dict1)

# %%
df
# Out:
#      Name  Age  Marks           Role
# 0   Virat   34     85        Batsman
# 1   Rohit   33     90        Batsman
# 2   Dhoni   40     75  wicket keeper
# 3  Jadeja   32     80    All rounder
# 4  Bumrah   30     70         Bowler
# 5   Shami   35     88         Bowler

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      Name  Age  Marks           Role
# 0   Virat   34     85        Batsman
# 1   Rohit   33     90        Batsman
# 2   Dhoni   40     75  wicket keeper
# 3  Jadeja   32     80    All rounder
# 4  Bumrah   30     70         Bowler

# %%
df.head(3)
# Out:
#     Name  Age  Marks           Role
# 0  Virat   34     85        Batsman
# 1  Rohit   33     90        Batsman
# 2  Dhoni   40     75  wicket keeper

# %%
df.tail()
# Out:
#      Name  Age  Marks           Role
# 1   Rohit   33     90        Batsman
# 2   Dhoni   40     75  wicket keeper
# 3  Jadeja   32     80    All rounder
# 4  Bumrah   30     70         Bowler
# 5   Shami   35     88         Bowler

# %%
df.tail(2)
# Out:
#      Name  Age  Marks    Role
# 4  Bumrah   30     70  Bowler
# 5   Shami   35     88  Bowler

# %%
## count the attribute
len(df)
# Out:
# 6

# %%
df.count()
# Out:
# Name     6
# Age      6
# Marks    6
# Role     6
# dtype: int64

# %%
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
df['Name']
# Out:
# 0     Virat
# 1     Rohit
# 2     Dhoni
# 3    Jadeja
# 4    Bumrah
# 5     Virat
# Name: Name, dtype: object

# %%
df['Name'].value_counts()
# Out:
# Name
# Virat     2
# Rohit     1
# Dhoni     1
# Jadeja    1
# Bumrah    1
# Name: count, dtype: int64

# %% [markdown]
# #### Basic Operations
#
# > Importing data set from different files.
#
#
# > Importing tabular dataset.

# %%
stock_df = pd.read_csv(r"C:\Users\klemp\OneDrive\Desktop\data analystic\data set\ETH_1h.csv")

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
## top 5 rows
stock_df.head()
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
## bottom 5 rows
stock_df.tail()
# Out:
#                    Date  Symbol    Open    High    Low   Close      Volume
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.0  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.0  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.1  275.01   679358.87

# %%
stock_df.head(10)
# Out:
#                Date  Symbol    Open    High     Low   Close      Volume
# 0  2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1  2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2  2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3  2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4  2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# 5  2020-03-13 03-PM  ETHUSD  128.39  128.90  116.06  124.85  7378976.00
# 6  2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 7  2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 8  2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# 9  2020-03-13 11-AM  ETHUSD  132.60  133.17  126.01  128.93  3311080.29

# %%
stock_df.tail(10)
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 23664  2017-07-01 08-PM  ETHUSD  258.49  262.00  257.12  258.17  2366698.50
# 23665  2017-07-01 07-PM  ETHUSD  259.50  260.88  253.23  258.49  3962669.00
# 23666  2017-07-01 06-PM  ETHUSD  263.51  266.73  255.27  259.50  5396852.35
# 23667  2017-07-01 05-PM  ETHUSD  268.00  268.44  262.39  263.51  1894983.33
# 23668  2017-07-01 04-PM  ETHUSD  272.57  272.57  267.60  268.00  1287300.75
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87

# %%
### Number of rows in dataframe
len(stock_df)
# Out:
# 23674

# %%
## Access column name of dataframe
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
stock_df.values
# Out:
# array([['2020-03-13 08-PM', 'ETHUSD', 129.94, ..., 126.87, 128.71,
#         1940673.93],
#        ['2020-03-13 07-PM', 'ETHUSD', 119.51, ..., 117.1, 129.94,
#         7579741.09],
#        ['2020-03-13 06-PM', 'ETHUSD', 124.47, ..., 115.5, 119.51,
#         4898735.81],
#        ...,
#        ['2017-07-01 01-PM', 'ETHUSD', 274.83, ..., 265.0, 268.79,
#         3010787.99],
#        ['2017-07-01 12-PM', 'ETHUSD', 275.01, ..., 271.0, 274.83,
#         824362.87],
#        ['2017-07-01 11-AM', 'ETHUSD', 279.98, ..., 272.1, 275.01,
#         679358.87]], dtype=object)

# %%
## accessing a column in data frame
stock_df['Open']
# Out:
# 0        129.94
# 1        119.51
# 2        124.47
# 3        124.08
# 4        124.85
#           ...
# 23669    265.74
# 23670    268.79
# 23671    274.83
# 23672    275.01
# 23673    279.98
# Name: Open, Length: 23674, dtype: float64

# %%
stock_df['Date']
# Out:
# 0        2020-03-13 08-PM
# 1        2020-03-13 07-PM
# 2        2020-03-13 06-PM
# 3        2020-03-13 05-PM
# 4        2020-03-13 04-PM
#                ...
# 23669    2017-07-01 03-PM
# 23670    2017-07-01 02-PM
# 23671    2017-07-01 01-PM
# 23672    2017-07-01 12-PM
# 23673    2017-07-01 11-AM
# Name: Date, Length: 23674, dtype: object

# %%
## accessing a  two or multiple  column in data frame
stock_df[['Open','Close']]
# Out:
#          Open   Close
# 0      129.94  128.71
# 1      119.51  129.94
# 2      124.47  119.51
# 3      124.08  124.47
# 4      124.85  124.08
# ...       ...     ...
# 23669  265.74  272.57
# 23670  268.79  265.74
# 23671  274.83  268.79
# 23672  275.01  274.83
# 23673  279.98  275.01
#
# [23674 rows x 2 columns]

# %%
stock_df[['Open','Close','Volume']]
# Out:
#          Open   Close      Volume
# 0      129.94  128.71  1940673.93
# 1      119.51  129.94  7579741.09
# 2      124.47  119.51  4898735.81
# 3      124.08  124.47  2753450.92
# 4      124.85  124.08  4461424.71
# ...       ...     ...         ...
# 23669  265.74  272.57  1500282.55
# 23670  268.79  265.74  1702536.85
# 23671  274.83  268.79  3010787.99
# 23672  275.01  274.83   824362.87
# 23673  279.98  275.01   679358.87
#
# [23674 rows x 3 columns]

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23674, step=1)

# %%
stock_df.columns
# Out:
# Index(['Date', 'Symbol', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %% [markdown]
# ### accessing rows
#
# >loc - label location

# %%
stock_df.loc[23672]
# Out:
# Date      2017-07-01 12-PM
# Symbol              ETHUSD
# Open                275.01
# High                275.01
# Low                  271.0
# Close               274.83
# Volume           824362.87
# Name: 23672, dtype: object

# %%
stock_df.loc[23672,'Date']
# Out:
# '2017-07-01 12-PM'

# %%
stock_df.loc[23672,['Date','Open','Close']]
# Out:
# Date     2017-07-01 12-PM
# Open               275.01
# Close              274.83
# Name: 23672, dtype: object

# %%
l = [1,2,3,4,5]
l[1:4]# slicing a list
# Out:
# [2, 3, 4]

# %%
 d2 = [[1,2,3],[4,5,6],[7,8,9]]
d2
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
d2[0][1]
# Out:
# 2

# %%
d2[1][1:3]
# Out:
# [5, 6]

# %% [markdown]
# ### Slicing in loc (labeled lacation)

# %%
stock_df.loc[23672,'Open':'Close'] # a:b , both a and b are inclusive
# Out:
# Open     275.01
# High     275.01
# Low       271.0
# Close    274.83
# Name: 23672, dtype: object

# %% [markdown]
# ## iloc - index based loction,when we dont know labels for rows and columns

# %%
stock_df.iloc[1,2]
# Out:
# np.float64(119.51)

# %%
stock_df.iloc[2,2]
# Out:
# np.float64(124.47)

# %%
stock_df.iloc[3,[2,4]] # multiple column index
# Out:
# Low           121.63
# Volume    2753450.92
# Name: 3, dtype: object

# %%
stock_df.iloc[2,2:6] # slicing
# Out:
# Open     124.47
# High     124.85
# Low       115.5
# Close    119.51
# Name: 2, dtype: object

# %%
stock_df.iloc[1:6,2:6]
# Out:
#      Open    High     Low   Close
# 1  119.51  132.02  117.10  129.94
# 2  124.47  124.85  115.50  119.51
# 3  124.08  127.42  121.63  124.47
# 4  124.85  129.51  120.17  124.08
# 5  128.39  128.90  116.06  124.85

# %% [markdown]
# #  filtring

# %%
stock_df['High']>130
# Out:
# 0         True
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 23669     True
# 23670     True
# 23671     True
# 23672     True
# 23673     True
# Name: High, Length: 23674, dtype: bool

# %%
f1=stock_df['High']>130

stock_gt_130=stock_df[f1]

# %%
stock_gt_130.reset_index(drop=True,inplace=True)

# %%
stock_gt_130
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 02-PM  ETHUSD  134.03  137.90  125.50  128.39  3733916.89
# 3      2020-03-13 01-PM  ETHUSD  131.35  140.95  128.99  134.03  9582732.93
# 4      2020-03-13 12-PM  ETHUSD  128.93  134.60  126.95  131.35  3906590.52
# ...                 ...     ...     ...     ...     ...     ...         ...
# 21608  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 21609  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 21610  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 21611  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 21612  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [21613 rows x 7 columns]

# %% [markdown]
# ## Adding new column

# %%
stock_df['Random_col']=list(range(1,len(stock_df)+1))

# %%
stock_df.index
# Out:
# RangeIndex(start=0, stop=23673, step=1)

# %%
 stock_df.iloc[len(stock_df)-1]
# Out:
# Date          2017-07-01 11-AM
# Symbol                  ETHUSD
# Open                    279.98
# High                    279.99
# Low                      272.1
# Close                   275.01
# Volume               679358.87
# Random_col               23674
# Name: 23673, dtype: object

# %%
len(stock_df)
# Out:
# 23674

# %%
for i in range(0,3):
    print(i)
# Out:
# 0
# 1
# 2

# %%
stock_df
# Out:
#                    Date  Symbol    Open    High     Low   Close      Volume  \
# 0      2020-03-13 08-PM  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#        Random_col
# 0               1
# ...

# %% [markdown]
# #### Droping Columns

# %%
stock_df.drop(columns=['High','Open'],inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...         ...
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  271.00  274.83   824362.87
# 23673  2017-07-01 11-AM  ETHUSD  272.10  275.01   679358.87
#
# [23674 rows x 5 columns]

# %% [markdown]
# ### Droping Rows

# %%
stock_df.drop(23673,axis=0,inplace=True)

# %%
stock_df
# Out:
#                    Date  Symbol     Low   Close      Volume
# 0      2020-03-13 08-PM  ETHUSD  126.87  128.71  1940673.93
# 1      2020-03-13 07-PM  ETHUSD  117.10  129.94  7579741.09
# 2      2020-03-13 06-PM  ETHUSD  115.50  119.51  4898735.81
# 3      2020-03-13 05-PM  ETHUSD  121.63  124.47  2753450.92
# 4      2020-03-13 04-PM  ETHUSD  120.17  124.08  4461424.71
# ...                 ...     ...     ...     ...         ...
# 23668  2017-07-01 04-PM  ETHUSD  267.60  268.00  1287300.75
# 23669  2017-07-01 03-PM  ETHUSD  265.00  272.57  1500282.55
# 23670  2017-07-01 02-PM  ETHUSD  265.00  265.74  1702536.85
# 23671  2017-07-01 01-PM  ETHUSD  265.00  268.79  3010787.99
# 23672  2017-07-01 12-PM  ETHUSD  271.00  274.83   824362.87
#
# [23673 rows x 5 columns]
